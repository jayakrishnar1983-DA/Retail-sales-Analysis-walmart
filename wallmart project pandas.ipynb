# %%
import pandas as pd

# %%
## importing dependencies
import pandas  as pd
## mysql toolkit
import pymysql
from sqlalchemy import create_engine

# %%
print(pd.__version__)

# %%
df=pd.read_csv("walmart.csv", encoding_errors='ignore')

# %%
df.shape

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
## all dupicates
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

# %%
df.shape

# %%
## all null values
df.isnull().sum()

# %%
## dropping all rows with missing records
df.dropna(inplace=True)
df.isnull().sum()

# %%
df.shape

# %%
df['unit_price']=df['unit_price'].str.replace('$','').astype(float)

# %%
df.head()

# %%
df.info()

# %%
df.columns

# %%
## created new column "total"
df['total'] = df['unit_price'] * df['quantity']
df.head()

# %%
#mysql
#host= localhost
#port= 3306
#user= root
#password= jay1234

# %%
df.shape

# %%
## mysql connection
## "mysql+mysqldb://user:password@localhost:3306/db_name"
engine_mysql = create_engine("mysql+pymysql://root:jay1234@localhost:3306/walmart_db")

try:
    engine_mysql
    print("connection successed to mysql")
except:
    print("unable to connect")

# %%
df.to_sql(name='walmart', con= engine_mysql, if_exists='append',index=False)
